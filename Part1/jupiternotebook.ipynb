# %%
x = 10

# %%
x
# Out:
# 10

# %%
z = 15

# %%
x = z + 2

# %%
x
# Out:
# 17

# %% [markdown]
# ## This is some text (title)
# Bla bla bla

# %% [markdown]
# Creating base-function

# %%
def add(a, b):
    return a + b

# %%
add(2,3)
# Out:
# 5

# %%
print(f"The result is:{add(2, 3)}")
# Out:
# The result is:5
